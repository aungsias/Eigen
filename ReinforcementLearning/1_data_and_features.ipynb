# %%
import yfinance as yf

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from datetime import datetime as dt
from snp500 import SNP500

# %%
tickers = ["BTC-USD", "ETH-USD", "LTC-USD", "XRP-USD"]

start = "2006-01-01"
end = dt.now()

data = yf.download(tickers, start, end).dropna()
data.head()

# %%
lookback = 50

close = data["Adj Close"]
open = data["Open"]
returns = np.log(close).diff()
std = returns.rolling(lookback).std()
momentum = close.pct_change(lookback)

close.columns = [f"{col}_close" for col in close]
open.columns = [f"{col}_open" for col in open]
returns.columns = [f"{col}_return" for col in returns]
std.columns = [f"{col}_std" for col in std]
momentum.columns = [f"{col}_momentum" for col in momentum]

features = pd.concat([close, open, returns, std, momentum], axis=1).dropna()
features.head()
# Out:
#             BTC-USD_close  ETH-USD_close  LTC-USD_close  XRP-USD_close  \
# Date
# 2017-12-29   14656.200195     753.591980     245.501999        2.21460
# 2017-12-30   12952.200195     717.257019     218.962997        2.15902
# 2017-12-31   14156.400391     756.732971     232.095993        2.30057
# 2018-01-01   13657.200195     772.640991     229.033005        2.39103
# 2018-01-02   14982.099609     884.443970     255.684006        2.48090
#
#             BTC-USD_return  ETH-USD_return  LTC-USD_return  XRP-USD_return  \
# Date
# 2017-12-29        0.003397        0.022232       -0.017876        0.436782
# 2017-12-30       -0.123598       -0.049417       -0.114402       -0.025417
# 2017-12-31        0.088901        0.053576        0.058248        0.063503
# 2018-01-01       -0.035900        0.020804       -0.013285        0.038567
# 2018-01-02        0.092589        0.135145        0.110076        0.036897
#
#             BTC-USD_std  ETH-USD_std  LTC-USD_std  XRP-USD_std  \
# Date
# ...

# %%
features.to_csv("workflow/data/features.csv")
