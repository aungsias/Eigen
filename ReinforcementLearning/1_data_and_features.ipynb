# %%
import pandas as pd
import yfinance as yf
import numpy as np
from snp500 import SNP500
from datetime import datetime as dt
from pprint import pprint

# %%
snp = SNP500()
sectors = snp.sector.copy()
sectors["GICS Sector"]= sectors["GICS Sector"].str.upper().str.replace(" ", "_")

sectors.head()
# Out:
#   Symbol             GICS Sector
# 0    MMM             INDUSTRIALS
# 1    AOS             INDUSTRIALS
# 2    ABT             HEALTH_CARE
# 3   ABBV             HEALTH_CARE
# 4    ACN  INFORMATION_TECHNOLOGY

# %%
sector_groups = sectors.groupby("GICS Sector")
tickers = sector_groups.sample(5, random_state=8)["Symbol"].to_list()

print(f'{", ".join(tickers[:5])}, ..., {", ".join(tickers[-5:])}')
# Out:
# EA, FOXA, CMCSA, MTCH, NFLX, ..., ETR, PNW, XEL, NEE, ATO

# %%
start = "2005-01-01"
end = dt.now().strftime("%Y-%m-%d")

prices_ = yf.download(tickers, start, end)["Adj Close"]
prices_ = prices_.dropna(axis=1)

prices_.head()
# Out:
# [*********************100%%**********************]  55 of 55 completed
#                   ACN        ATO        AZO       CBRE        CCI   CDNS  \
# Date
# 2005-01-03  18.995512  14.065578  90.750000  10.983333  11.480591  13.75
# 2005-01-04  18.548901  14.102574  89.699997  10.920000  11.298692  13.30
# 2005-01-05  18.476866  14.007429  90.290001  10.606667  11.578533  13.31
# 2005-01-06  18.311184  13.975715  89.550003  10.723333  11.648497  13.34
# 2005-01-07  19.168392  13.880570  89.730003  10.733333  11.928338  13.28
#
#                CMCSA        COF        CPB       CSX  ...       PWR  \
# Date                                                  ...
# 2005-01-03  8.040770  63.524788  17.212313  1.605051  ...  7.928757
# 2005-01-04  7.835287  62.349834  17.316589  1.570387  ...  7.574617
# 2005-01-05  7.908674  61.728230  17.183340  1.564340  ...  7.672988
# 2005-01-06  7.896441  62.501431  17.183340  1.583285  ...  7.653314
# 2005-01-07  7.967382  62.129990  17.038504  1.565952  ...  7.613965
#
#                  RVTY      SCHW        SEE        SLB        SPG        STZ  \
# Date
# 2005-01-03  19.054310  8.899646  19.451067  22.085529  27.702084  20.799591
# 2005-01-04  18.821409  8.693563  18.813562  21.917099  27.398846  20.593653
# 2005-01-05  18.260733  8.640132  18.335436  21.985849  26.185944  20.016142
# 2005-01-06  18.441881  8.785159  18.375284  22.415524  26.419861  20.813021
# 2005-01-07  18.433252  8.754629  18.469456  21.838032  26.536810  21.994923
#
#                   TXN       XEL        XOM
# Date
# 2005-01-03  16.129154  8.957226  26.912636
# 2005-01-04  15.742270  8.823017  26.729958
# 2005-01-05  15.268669  8.723604  26.590258
# 2005-01-06  15.208624  8.708690  26.928753
# 2005-01-07  15.288682  8.658986  26.751440
#
# [5 rows x 46 columns]

# %%
available_tickers = prices_.columns
trimmed_sectors = sectors[sectors["Symbol"].isin(available_tickers)]

sample = trimmed_sectors.groupby("GICS Sector").sample(1, random_state=8)
sampled_stocks = sample["Symbol"].to_list()
sampled_sectors = sample["GICS Sector"].to_list()

print(sampled_stocks, "\n")
pprint(sampled_sectors)
# Out:
# ['MTCH', 'AZO', 'PEP', 'XOM', 'COF', 'RVTY', 'GE', 'CDNS', 'FCX', 'EQR', 'XEL']
#
# ['COMMUNICATION_SERVICES',
#  'CONSUMER_DISCRETIONARY',
#  'CONSUMER_STAPLES',
#  'ENERGY',
#  'FINANCIALS',
#  'HEALTH_CARE',
#  'INDUSTRIALS',
#  'INFORMATION_TECHNOLOGY',
#  'MATERIALS',
#  'REAL_ESTATE',
#  'UTILITIES']

# %%
prices = prices_[sampled_stocks].copy()
prices.head()
# Out:
#                 MTCH        AZO        PEP        XOM        COF       RVTY  \
# Date
# 2005-01-03  6.387365  90.750000  31.033430  26.912636  63.524788  19.054310
# 2005-01-04  6.262746  89.699997  30.812344  26.729958  62.349834  18.821409
# 2005-01-05  6.213877  90.290001  30.848204  26.590258  61.728230  18.260733
# 2005-01-06  6.196771  89.550003  31.069269  26.928753  62.501431  18.441881
# 2005-01-07  6.257859  89.730003  31.338142  26.751440  62.129990  18.433252
#
#                     GE   CDNS        FCX        EQR       XEL
# Date
# 2005-01-03  133.530838  13.75  11.550533  15.048333  8.957226
# 2005-01-04  131.925140  13.30  11.094222  14.954946  8.823017
# 2005-01-05  131.122208  13.31  10.966949  14.475262  8.723604
# 2005-01-06  132.180527  13.34  10.951435  14.475262  8.708690
# 2005-01-07  131.377762  13.28  11.056971  14.411595  8.658986

# %%
returns = np.log(prices).diff()
returns.columns = [f"{col}_RET" for col in returns]

features = pd.concat([prices, returns], axis=1).dropna()
features.head()
# Out:
#                 MTCH        AZO        PEP        XOM        COF       RVTY  \
# Date
# 2005-01-04  6.262746  89.699997  30.812344  26.729958  62.349834  18.821409
# 2005-01-05  6.213877  90.290001  30.848204  26.590258  61.728230  18.260733
# 2005-01-06  6.196771  89.550003  31.069269  26.928753  62.501431  18.441881
# 2005-01-07  6.257859  89.730003  31.338142  26.751440  62.129990  18.433252
# 2005-01-10  6.270078  90.739998  32.120846  26.853527  62.395287  18.459126
#
#                     GE   CDNS        FCX        EQR  ...   AZO_RET   PEP_RET  \
# Date                                                 ...
# 2005-01-04  131.925140  13.30  11.094222  14.954946  ... -0.011638 -0.007150
# 2005-01-05  131.122208  13.31  10.966949  14.475262  ...  0.006556  0.001163
# 2005-01-06  132.180527  13.34  10.951435  14.475262  ... -0.008230  0.007141
# 2005-01-07  131.377762  13.28  11.056971  14.411595  ...  0.002008  0.008617
# 2005-01-10  131.049286  13.37  10.997992  14.326694  ...  0.011193  0.024669
#
#              XOM_RET   COF_RET  RVTY_RET    GE_RET  CDNS_RET   FCX_RET  \
# Date
# 2005-01-04 -0.006811 -0.018669 -0.012298 -0.012098 -0.033275 -0.040307
# 2005-01-05 -0.005240 -0.010020 -0.030242 -0.006105  0.000752 -0.011538
# 2005-01-06  0.012650  0.012448  0.009871  0.008039  0.002251 -0.001416
# 2005-01-07 -0.006606 -0.005961 -0.000468 -0.006092 -0.004508  0.009591
# 2005-01-10  0.003809  0.004261  0.001403 -0.002503  0.006754 -0.005348
#
#              EQR_RET   XEL_RET
# Date
# 2005-01-04 -0.006225 -0.015097
# 2005-01-05 -0.032601 -0.011331
# 2005-01-06  0.000000 -0.001711
# 2005-01-07 -0.004408 -0.005724
# 2005-01-10 -0.005909  0.013683
#
# [5 rows x 22 columns]

# %%
prices.to_csv("workflow/data/prices.csv")
returns.to_csv("workflow/data/returns.csv")
features.to_csv("workflow/data/features.csv")

# %%
np.array([0, 1]).std()
# Out:
# 0.5
