# %%
import pandas as pd
from workflow import simulacrum as sim

df = pd.read_csv("workflow/data/supply_chain_data.csv")
df.columns = [i.lower().strip().replace(" ", "_") for i in df.columns]

# %%
sim.generate_random_value(df, "revenue_generated", prob=True)
# Out:
# (7014.887987203389,
#  {8661.996792392383: 0.01,
#   4256.949140850225: 0.01,
#   7910.886916140686: 0.01,
#   2633.121981312256: 0.01,
#   8180.337085425443: 0.01,
#   7014.887987203389: 0.01,
#   1752.3810874841247: 0.01,
#   3550.218432780992: 0.01,
#   9473.798032508335: 0.01,
#   8367.721618020154: 0.01,
#   8354.579686481995: 0.01,
#   8458.730878367178: 0.01,
#   3899.746833729224: 0.01,
#   7460.900065445849: 0.01,
#   6885.589350896253: 0.01,
#   8864.084349586436: 0.01,
#   1061.618523013288: 0.01,
#   2021.149810337108: 0.01,
#   1605.8669003924058: 0.01,
#   4767.020484344137: 0.01,
#   2925.6751703038126: 0.01,
#   6088.021479940859: 0.01,
#   8232.334829425821: 0.01,
#   9435.76260891213: 0.01,
#   5709.945295969287: 0.01,
#   1889.073589779335: 0.01,
#   5328.375984297758: 0.01,
#   2483.7601775427947: 0.01,
#   8525.952559683526: 0.01,
#   4370.916579984536: 0.01,
#   7698.424765632117: 0.01,
#   7386.363944048664: 0.01,
#   7888.356546661873: 0.01,
# ...

# %%
df
# Out:
#    product_type    sku      price  availability  number_of_products_sold  \
# 0      haircare   SKU0  69.808006            55                      802
# 1      skincare   SKU1  14.843523            95                      736
# 2      haircare   SKU2  11.319683            34                        8
# 3      skincare   SKU3  61.163343            68                       83
# 4      skincare   SKU4   4.805496            26                      871
# ..          ...    ...        ...           ...                      ...
# 95     haircare  SKU95  77.903927            65                      672
# 96    cosmetics  SKU96  24.423131            29                      324
# 97     haircare  SKU97   3.526111            56                       62
# 98     skincare  SKU98  19.754605            43                      913
# 99     haircare  SKU99  68.517833            17                      627
#
#     revenue_generated customer_demographics  stock_levels  lead_times  \
# ...
