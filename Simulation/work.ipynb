# %% [markdown]
# # Optimizing a Supply Chain
#
# Aung Si<br>
# January 23<sup>rd</sup>, 2024

# %% [markdown]
# ---

# %% [markdown]
# ## Problem Breakdown
#
# **Objective:** Minimize Order Fulfilment Costs
#
# Fulfilment costs are broken down into:
# - Storage costs
# - Freight costs
#
# \begin{aligned}
# \text{total fulfilment cost } (\mathbb{C}) = \text{total transportation cost } (\mathbf{T}) + \text{total storage cost } (\mathbf{S})
# \end{aligned}
#
# \begin{aligned}
#
# \sum^m_{i=1}Q_{ij} (T_{ijr} + S_{ijp})
# \end{aligned}

# %%
import pandas as pd

pd.read_csv("workflow/data/FreightRates.csv")
# Out:
#       Unnamed: 0 Carrier orig_port_cd dest_port_cd  minm_wgh_qty  max_wgh_qty  \
# 0              0  V444_6       PORT08       PORT09         250.0       499.99
# 1              1  V444_6       PORT08       PORT09          65.0        69.99
# 2              2  V444_6       PORT08       PORT09          60.0        64.99
# 3              3  V444_6       PORT08       PORT09          50.0        54.99
# 4              4  V444_6       PORT08       PORT09          35.0        39.99
# ...          ...     ...          ...          ...           ...          ...
# 1535        1535  V444_8       PORT03       PORT09           0.0        99.99
# 1536        1536  V444_8       PORT03       PORT09         500.0      1999.99
# 1537        1537  V444_8       PORT03       PORT09         250.0       499.99
# 1538        1538  V444_8       PORT03       PORT09        2000.0     99999.99
# 1539        1539  V444_8       PORT03       PORT09         100.0       249.99
#
# ...
