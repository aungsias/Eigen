# %%
import pandas as pd
import yfinance as yf

# %%
snp_url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
snp_table = pd.read_html(snp_url)[0]

snp_table.head()
# Out:
#   Symbol     Security             GICS Sector               GICS Sub-Industry  \
# 0    MMM           3M             Industrials        Industrial Conglomerates
# 1    AOS  A. O. Smith             Industrials               Building Products
# 2    ABT       Abbott             Health Care           Health Care Equipment
# 3   ABBV       AbbVie             Health Care                 Pharmaceuticals
# 4    ACN    Accenture  Information Technology  IT Consulting & Other Services
#
#      Headquarters Location  Date added      CIK      Founded
# 0    Saint Paul, Minnesota  1957-03-04    66740         1902
# 1     Milwaukee, Wisconsin  2017-07-26    91142         1916
# 2  North Chicago, Illinois  1957-03-04     1800         1888
# 3  North Chicago, Illinois  2012-12-31  1551152  2013 (1888)
# 4          Dublin, Ireland  2011-07-06  1467373         1989

# %%
snp_tickers = snp_table["Symbol"].to_list()
snp_tickers = [ticker.replace('.', "-") for ticker in snp_tickers]
snp_tickers_by_sector = snp_table[["Symbol", "GICS Sector"]]

snp_tickers_by_sector.head()
# Out:
#   Symbol             GICS Sector
# 0    MMM             Industrials
# 1    AOS             Industrials
# 2    ABT             Health Care
# 3   ABBV             Health Care
# 4    ACN  Information Technology

# %%
start_date = "1990-01-01"
end_date = "2023-09-12"

snp_prices = yf.download(snp_tickers, start_date, end_date)["Adj Close"]
# Out:
# [*********************100%***********************]  503 of 503 completed

# %%
snp_prices.head(3)
# Out:
#              A  AAL      AAPL  ABBV       ABT  ACGL  ACN      ADBE       ADI  \
# Date
# 1990-01-02 NaN  NaN  0.263761   NaN  1.837212   NaN  NaN  1.188340  1.021221
# 1990-01-03 NaN  NaN  0.265531   NaN  1.843845   NaN  NaN  1.247023  0.968170
# 1990-01-04 NaN  NaN  0.266417   NaN  1.840528   NaN  NaN  1.305707  0.954908
#
#                  ADM  ...  WYNN       XEL       XOM      XRAY  XYL  YUM  ZBH  \
# Date                  ...
# 1990-01-02  4.656209  ...   NaN  4.213068  4.034966  0.855866  NaN  NaN  NaN
# 1990-01-03  4.656209  ...   NaN  4.200066  3.994620  0.855866  NaN  NaN  NaN
# 1990-01-04  4.630907  ...   NaN  4.096035  3.954270  0.821631  NaN  NaN  NaN
#
#             ZBRA      ZION  ZTS
# Date
# 1990-01-02   NaN  1.818957  NaN
# 1990-01-03   NaN  1.851439  NaN
# 1990-01-04   NaN  1.851439  NaN
#
# [3 rows x 503 columns]

# %%
len(snp_prices)
# Out:
# 8488

# %%
indices = {
    "VTI": "STOCKS",
    "AGG": "BONDS",
    "DBC": "COMMODITIES",
    "^VIX": "VOLATILITY"
}

indices_prices = yf.download(list(indices.keys()), start_date, end_date)["Adj Close"].dropna()
indices_prices.rename(columns=indices, inplace=True)

indices_prices.head(3)
# Out:
# [*********************100%***********************]  4 of 4 completed
#                 BONDS  COMMODITIES     STOCKS  VOLATILITY
# Date
# 2006-02-06  58.718147    21.916014  45.468452       13.04
# 2006-02-07  58.677162    21.282080  45.025742       13.59
# 2006-02-08  58.647850    21.191517  45.349682       12.83

# %%
len(indices_prices)
# Out:
# 4429

# %%
snp_prices_reindexed = snp_prices.reindex(indices_prices.index).dropna(axis=1)
snp_prices_reindexed.head(3)
# Out:
#                     A        AAL      AAPL        ABT      ACGL        ACN  \
# Date
# 2006-02-06  21.155682  27.594042  2.040143  13.528105  6.003333  23.419563
# 2006-02-07  20.705034  27.339506  2.049237  13.429254  5.937778  23.639191
# 2006-02-08  21.033888  28.272818  2.085917  13.413301  5.885556  23.749002
#
#                  ADBE        ADI        ADM        ADP  ...        WTW  \
# Date                                                    ...
# 2006-02-06  39.520000  25.989521  19.771849  22.702063  ...  60.795563
# 2006-02-07  39.259998  26.118898  19.871237  22.846333  ...  61.587666
# 2006-02-08  38.799999  26.455246  20.288673  23.258522  ...  62.731754
#
#                    WY       WYNN       XEL        XOM       XRAY        YUM  \
# Date
# 2006-02-06  13.990589  34.024216  9.861901  33.966381  23.323494  13.171959
# 2006-02-07  13.916323  33.315826  9.714868  33.188068  23.336805  13.014937
# 2006-02-08  13.990589  33.167553  9.615091  33.276222  23.394472  12.865635
#
#                   ZBH       ZBRA       ZION
# Date
# 2006-02-06  58.793865  43.349998  58.166370
# 2006-02-07  59.287476  44.000000  57.862595
# 2006-02-08  59.613647  46.180000  58.307129
#
# [3 rows x 419 columns]

# %%
indices_prices.to_csv("data/indices.csv")

# %%
snp_prices_reindexed.to_csv("data/snp_prices.csv")

# %%
snp_tickers_by_sector.to_csv("data/stocks_by_sector.csv")
